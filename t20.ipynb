# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
from yaml import safe_load
import os

# %%
filesname = []
for file in os.listdir('/content/drive/MyDrive/datasets/t20s'):
  filesname.append(os.path.join(file))

# %%
filesname

# %%
final_df= pd.DataFrame()
counter = 1
for file in tqdm(filesname):
  with open('/content/drive/MyDrive/datasets/t20s/'+file,'r') as f:
    df= pd.json_normalize(safe_load(f))
    df['match_id'] = counter
    final_df= final_df.append(df)
    counter+=1

final_df

# %%
backup = final_df.copy()

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1432 entries, 0 to 0
# Data columns (total 28 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   innings                      1432 non-null   object
#  1   meta.data_version            1432 non-null   float64
#  2   meta.created                 1432 non-null   object
#  3   meta.revision                1432 non-null   int64
#  4   info.city                    1240 non-null   object
#  5   info.dates                   1432 non-null   object
#  6   info.gender                  1432 non-null   object
#  7   info.match_type              1432 non-null   object
#  8   info.match_type_number       699 non-null    float64
#  9   info.outcome.result          46 non-null     object
#  10  info.outcome.eliminator      16 non-null     object
#  11  info.overs                   1432 non-null   int64
#  12  info.player_of_match         1269 non-null   object
# ...

# %%
final_df.drop(columns=['meta.data_version',
                       'meta.created',
                       'meta.revision',
                       'info.outcome.bowl_out',
                       'info.bowl_out',
                       'info.supersubs.New Zealand',
                       'info.supersubs.South Africa',
                       'info.outcome.eliminator',
                       'info.outcome.result',
                       'info.outcome.method',
                       'info.neutral_venue',
                       'info.match_type_number',
                       'info.outcome.by.runs',
                       'info.outcome.by.wickets'
                       ],inplace= True)

# %%
final_df['info.gender'].value_counts()
# Out:
# male      966
# female    466
# Name: info.gender, dtype: int64

# %%
final_df
# Out:
#                                               innings         info.city  \
# 0   [{'1st innings': {'team': 'Ireland', 'deliveri...     Greater Noida
# 0   [{'1st innings': {'team': 'West Indies', 'deli...        Lauderhill
# 0   [{'1st innings': {'team': 'England', 'deliveri...            Sydney
# 0   [{'1st innings': {'team': 'Japan', 'deliveries...         Port Vila
# 0   [{'1st innings': {'team': 'Pakistan', 'deliver...  Pietermaritzburg
# ..                                                ...               ...
# 0   [{'1st innings': {'team': 'Sri Lanka', 'delive...             Perth
# 0   [{'1st innings': {'team': 'India', 'deliveries...            Guyana
# 0   [{'1st innings': {'team': 'Botswana', 'deliver...          Windhoek
# 0   [{'1st innings': {'team': 'New Zealand', 'deli...   Mount Maunganui
# 0   [{'1st innings': {'team': 'Zimbabwe', 'deliver...               NaN
#
#       info.dates info.gender info.match_type  info.overs info.player_of_match  \
# ...

# %%
final_df = final_df[final_df['info.gender']=='male']
final_df.drop(columns = ['info.gender'],inplace= True)
final_df
# Out:
# <ipython-input-17-3a9d47ee3487>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df.drop(columns = ['info.gender'],inplace= True)
#                                               innings      info.city  \
# 0   [{'1st innings': {'team': 'Ireland', 'deliveri...  Greater Noida
# 0   [{'1st innings': {'team': 'West Indies', 'deli...     Lauderhill
# 0   [{'1st innings': {'team': 'United Arab Emirate...      Abu Dhabi
# 0   [{'1st innings': {'team': 'Singapore', 'delive...        Bangkok
# 0   [{'1st innings': {'team': 'India', 'deliveries...            NaN
# ..                                                ...            ...
# 0   [{'1st innings': {'team': 'Kenya', 'deliveries...          Dubai
# 0   [{'1st innings': {'team': 'Nepal', 'deliveries...      Al Amarat
# ...

# %%
final_df['info.match_type'].value_counts()
final_df['info.overs'].value_counts()
# Out:
# 20    963
# 50      3
# Name: info.overs, dtype: int64

# %%
final_df = final_df[final_df['info.overs']==20]
final_df.drop(columns = ['info.overs','info.match_type'],inplace= True)
final_df
# Out:
# <ipython-input-19-ed4684dc61e0>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df.drop(columns = ['info.overs','info.match_type'],inplace= True)
#                                               innings      info.city  \
# 0   [{'1st innings': {'team': 'Ireland', 'deliveri...  Greater Noida
# 0   [{'1st innings': {'team': 'West Indies', 'deli...     Lauderhill
# 0   [{'1st innings': {'team': 'United Arab Emirate...      Abu Dhabi
# 0   [{'1st innings': {'team': 'Singapore', 'delive...        Bangkok
# 0   [{'1st innings': {'team': 'India', 'deliveries...            NaN
# ..                                                ...            ...
# 0   [{'1st innings': {'team': 'Kenya', 'deliveries...          Dubai
# 0   [{'1st innings': {'team': 'Nepal', 'deliveries...      Al Amarat
# ...

# %%
import pickle
pickle.dump(final_df,open('dataset_level1.pkl','wb'))

# %%
import pickle
matches = pickle.load(open('dataset_level1.pkl','rb'))
matches
# Out:
#                                               innings      info.city  \
# 0   [{'1st innings': {'team': 'Ireland', 'deliveri...  Greater Noida
# 0   [{'1st innings': {'team': 'West Indies', 'deli...     Lauderhill
# 0   [{'1st innings': {'team': 'United Arab Emirate...      Abu Dhabi
# 0   [{'1st innings': {'team': 'Singapore', 'delive...        Bangkok
# 0   [{'1st innings': {'team': 'India', 'deliveries...            NaN
# ..                                                ...            ...
# 0   [{'1st innings': {'team': 'Kenya', 'deliveries...          Dubai
# 0   [{'1st innings': {'team': 'Nepal', 'deliveries...      Al Amarat
# 0   [{'1st innings': {'team': 'Singapore', 'delive...      Singapore
# 0   [{'1st innings': {'team': 'Botswana', 'deliver...       Windhoek
# 0   [{'1st innings': {'team': 'Zimbabwe', 'deliver...            NaN
#
#       info.dates info.player_of_match                      info.teams  \
# ...

# %%
import pandas as pd
count = 1
delivery_df = pd.DataFrame()
for index, row in matches.iterrows():
    if count in [75,108,150,180,268,360,443,458,584,748,982,1052,1111,1226,1345]:
        count+=1
        continue
    count+=1
    ball_of_match = []
    batsman = []
    bowler = []
    runs = []
    player_of_dismissed = []
    teams = []
    batting_team = []
    match_id = []
    city = []
    venue = []
    for ball in row['innings'][0]['1st innings']['deliveries']:
        for key in ball.keys():
            match_id.append(count)
            batting_team.append(row['innings'][0]['1st innings']['team'])
            teams.append(row['info.teams'])
            ball_of_match.append(key)
            batsman.append(ball[key]['batsman'])
            bowler.append(ball[key]['bowler'])
            runs.append(ball[key]['runs']['total'])
            city.append(row['info.city'])
            venue.append(row['info.venue'])
            try:
                player_of_dismissed.append(ball[key]['wicket']['player_out'])
            except:
                player_of_dismissed.append('0')
    loop_df = pd.DataFrame({
            'match_id':match_id,
            'teams':teams,
            'batting_team':batting_team,
            'ball':ball_of_match,
            'batsman':batsman,
            'bowler':bowler,
            'runs':runs,
            'player_dismissed':player_of_dismissed,
            'city':city,
            'venue':venue
        })
    delivery_df = delivery_df.append(loop_df)

# %%
delivery_df

# %%
def bowl(row):
  for team in row['teams']:
    if team!= row['batting_team']:
      return team

# %%
delivery_df['bowling_team'] = delivery_df.apply(bowl,axis=1)

# %%
delivery_df

# %%
delivery_df.drop(columns=['teams'],inplace= True)

# %%
delivery_df['bowling_team'].unique()
# Out:
# array(['Afghanistan', 'India', 'Canada', 'Thailand', 'Zimbabwe', 'Oman',
#        'Ireland', 'Singapore', 'Sri Lanka', 'West Indies', 'Australia',
#        'Scotland', 'New Zealand', 'South Africa', 'Norway', 'Pakistan',
#        'Nepal', 'England', 'Netherlands', 'Italy', 'Bulgaria', 'Qatar',
#        'Guernsey', 'United Arab Emirates', 'Bangladesh', 'Namibia',
#        'Czech Republic', 'Germany', 'Kenya', 'Nigeria', 'Hong Kong',
#        'Papua New Guinea', 'Maldives', 'Spain', 'Kuwait', 'Ghana',
#        'Malaysia', 'Botswana', 'Romania', 'Bahrain', 'ICC World XI',
#        'Saudi Arabia', 'United States of America', 'Portugal',
#        'Luxembourg', 'Bermuda', 'Vanuatu', 'Bhutan', 'Denmark', 'Uganda',
#        'Philippines', 'Jersey', 'Cayman Islands'], dtype=object)

# %%
abc= delivery_df.copy()

# %%
teams=['Australia',
    'India',
    'Bangladesh',
    'New Zealand',
    'South Africa',
    'England',
    'West Indies',
    'Afghanistan',
    'Pakistan',
    'Sri Lanka'
       ]

# %%
delivery_df= delivery_df[delivery_df['batting_team'].isin(teams)]
delivery_df= delivery_df[delivery_df['bowling_team'].isin(teams)]

# %%
delivery_df
# Out:
#      match_id  batting_team  ball            batsman          bowler  runs  \
# 0           3   West Indies   0.1          J Charles  Mohammed Shami     1
# 1           3   West Indies   0.2          J Charles  Mohammed Shami     0
# 2           3   West Indies   0.3          J Charles  Mohammed Shami     6
# 3           3   West Indies   0.4          J Charles  Mohammed Shami     4
# 4           3   West Indies   0.5          J Charles  Mohammed Shami     1
# ..        ...           ...   ...                ...             ...   ...
# 120       957  South Africa  19.2  HE van der Dussen       TK Curran     0
# 121       957  South Africa  19.3  HE van der Dussen       TK Curran     1
# 122       957  South Africa  19.4           K Rabada       TK Curran     0
# 123       957  South Africa  19.5           K Rabada       TK Curran     4
# 124       957  South Africa  19.6           K Rabada       TK Curran     1
#
#     player_dismissed        city  \
# ...

# %%
output = delivery_df[['match_id','batting_team','bowling_team','ball','runs','player_dismissed','city','venue']]

# %%
output
# Out:
#      match_id  batting_team bowling_team  ball  runs player_dismissed  \
# 0           3   West Indies        India   0.1     1                0
# 1           3   West Indies        India   0.2     0                0
# 2           3   West Indies        India   0.3     6                0
# 3           3   West Indies        India   0.4     4                0
# 4           3   West Indies        India   0.5     1                0
# ..        ...           ...          ...   ...   ...              ...
# 120       957  South Africa      England  19.2     0                0
# 121       957  South Africa      England  19.3     1                0
# 122       957  South Africa      England  19.4     0                0
# 123       957  South Africa      England  19.5     4                0
# 124       957  South Africa      England  19.6     1                0
#
#            city                                              venue
# ...

# %%
pickle.dump(output,open('dataset_level2.pkl','wb'))

# %%
import pickle
output = pickle.load(open('dataset_level2.pkl','rb'))
output

# %%
output.isnull().sum()
# Out:
# match_id               0
# batting_team           0
# bowling_team           0
# ball                   0
# runs                   0
# player_dismissed       0
# city                8671
# venue                  0
# dtype: int64

# %%
output[output['city'].isnull()]['venue'].value_counts()
# Out:
# Dubai International Cricket Stadium        3092
# Pallekele International Cricket Stadium    2066
# Melbourne Cricket Ground                   1453
# Sydney Cricket Ground                       749
# Adelaide Oval                               498
# Harare Sports Club                          372
# Sharjah Cricket Stadium                     249
# Sylhet International Cricket Stadium        128
# Carrara Oval                                 64
# Name: venue, dtype: int64

# %%
df= output.copy()

# %%
import numpy as np
cities= np.where(df['city'].isnull(),df['venue'].str.split().apply(lambda x:x[0]),df['city'])

# %%
df['city']= cities

# %%
df.isnull().sum()
# Out:
# match_id            0
# batting_team        0
# bowling_team        0
# ball                0
# runs                0
# player_dismissed    0
# city                0
# venue               0
# dtype: int64

# %%
df.drop(columns=['venue'],inplace=True)

# %%
df
# Out:
#      match_id  batting_team bowling_team  ball  runs player_dismissed  \
# 0           3   West Indies        India   0.1     1                0
# 1           3   West Indies        India   0.2     0                0
# 2           3   West Indies        India   0.3     6                0
# 3           3   West Indies        India   0.4     4                0
# 4           3   West Indies        India   0.5     1                0
# ..        ...           ...          ...   ...   ...              ...
# 120       957  South Africa      England  19.2     0                0
# 121       957  South Africa      England  19.3     1                0
# 122       957  South Africa      England  19.4     0                0
# 123       957  South Africa      England  19.5     4                0
# 124       957  South Africa      England  19.6     1                0
#
#            city
# 0    Lauderhill
# 1    Lauderhill
# 2    Lauderhill
# 3    Lauderhill
# 4    Lauderhill
# ..          ...
# ...

# %%
selected_city=df['city'].value_counts()[df['city'].value_counts() > 600].index.tolist()

# %%
selected_city
# Out:
# ['Colombo',
#  'Mirpur',
#  'Johannesburg',
#  'Dubai',
#  'Auckland',
#  'Cape Town',
#  'London',
#  'Pallekele',
#  'Barbados',
#  'Melbourne',
#  'Durban',
#  'St Lucia',
#  'Wellington',
#  'Sydney',
#  'Lauderhill',
#  'Hamilton',
#  'Centurion',
#  'Abu Dhabi',
#  'Manchester',
#  'Mumbai',
#  'Nottingham',
#  'Southampton',
#  'Mount Maunganui',
#  'Chittagong',
#  'Kolkata',
#  'Lahore',
#  'Delhi',
#  'Nagpur',
#  'Cardiff',
#  'Chandigarh',
#  'Adelaide',
#  'Bangalore',
#  'St Kitts',
#  'Christchurch',
#  'Trinidad']

# %%
df= df[df['city'].isin(selected_city)]

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           3  West Indies        India   0.1     1                0
# 1           3  West Indies        India   0.2     0                0
# 2           3  West Indies        India   0.3     6                0
# 3           3  West Indies        India   0.4     4                0
# 4           3  West Indies        India   0.5     1                0
# ..        ...          ...          ...   ...   ...              ...
# 116       954  New Zealand      England  19.2     1                0
# 117       954  New Zealand      England  19.3     0      LRPL Taylor
# 118       954  New Zealand      England  19.4     1                0
# 119       954  New Zealand      England  19.5     1                0
# 120       954  New Zealand      England  19.6     2                0
#
#              city
# 0      Lauderhill
# 1      Lauderhill
# 2      Lauderhill
# 3      Lauderhill
# 4      Lauderhill
# ..            ...
# ...

# %%
df['current_score']= df.groupby('match_id').cumsum()['runs']
# Out:
# <ipython-input-94-0de16729d4c7>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.cumsum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df['current_score']= df.groupby('match_id').cumsum()['runs']
# <ipython-input-94-0de16729d4c7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['current_score']= df.groupby('match_id').cumsum()['runs']

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           3  West Indies        India   0.1     1                0
# 1           3  West Indies        India   0.2     0                0
# 2           3  West Indies        India   0.3     6                0
# 3           3  West Indies        India   0.4     4                0
# 4           3  West Indies        India   0.5     1                0
# ..        ...          ...          ...   ...   ...              ...
# 116       954  New Zealand      England  19.2     1                0
# 117       954  New Zealand      England  19.3     0      LRPL Taylor
# 118       954  New Zealand      England  19.4     1                0
# 119       954  New Zealand      England  19.5     1                0
# 120       954  New Zealand      England  19.6     2                0
#
#              city  current_score
# 0      Lauderhill              1
# 1      Lauderhill              1
# 2      Lauderhill              7
# ...

# %%
df['over']= df['ball'].apply(lambda x: str(x).split(".")[0])
df['ball_no'] = df['ball'].apply(lambda x: str(x).split(".")[1])
df
# Out:
# <ipython-input-96-2f0e09581f5b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['over']= df['ball'].apply(lambda x: str(x).split(".")[0])
# <ipython-input-96-2f0e09581f5b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ball_no'] = df['ball'].apply(lambda x: str(x).split(".")[1])
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           3  West Indies        India   0.1     1                0
# ...

# %%
df['balls_bowled'] = (df['over'].astype('int')*6)+ df['ball_no'].astype('int')
df
# Out:
# <ipython-input-97-a3233853409b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['balls_bowled'] = (df['over'].astype('int')*6)+ df['ball_no'].astype('int')
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           3  West Indies        India   0.1     1                0
# 1           3  West Indies        India   0.2     0                0
# 2           3  West Indies        India   0.3     6                0
# 3           3  West Indies        India   0.4     4                0
# 4           3  West Indies        India   0.5     1                0
# ..        ...          ...          ...   ...   ...              ...
# 116       954  New Zealand      England  19.2     1                0
# ...

# %%
df['balls_left'] = 120- df['balls_bowled']
df['balls_left'] = df['balls_left'].apply(lambda x:0 if x<0 else x)
df
# Out:
# <ipython-input-98-13a7e0581dbc>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['balls_left'] = 120- df['balls_bowled']
# <ipython-input-98-13a7e0581dbc>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['balls_left'] = df['balls_left'].apply(lambda x:0 if x<0 else x)
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           3  West Indies        India   0.1     1                0
# 1           3  West Indies        India   0.2     0                0
# ...

# %%
df['player_dismissed'] = df['player_dismissed'].apply(lambda x:0 if x=='0' else 1)
df['player_dismissed'] = df['player_dismissed'].astype('int')
df['player_dismissed'] = df.groupby('match_id').cumsum()['player_dismissed']
df['wickets_left'] = 10 - df['player_dismissed']
df
# Out:
# <ipython-input-99-cfa3ce2b0c18>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['player_dismissed'] = df['player_dismissed'].apply(lambda x:0 if x=='0' else 1)
# <ipython-input-99-cfa3ce2b0c18>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['player_dismissed'] = df['player_dismissed'].astype('int')
# ...

# %%
df['crr'] = (df['current_score']*6)/df['balls_bowled']
df
# Out:
# <ipython-input-100-dd66b92f3bcf>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['crr'] = (df['current_score']*6)/df['balls_bowled']
#      match_id batting_team bowling_team  ball  runs  player_dismissed  \
# 0           3  West Indies        India   0.1     1                 0
# 1           3  West Indies        India   0.2     0                 0
# 2           3  West Indies        India   0.3     6                 0
# 3           3  West Indies        India   0.4     4                 0
# 4           3  West Indies        India   0.5     1                 0
# ..        ...          ...          ...   ...   ...               ...
# 116       954  New Zealand      England  19.2     1                 4
# ...

# %%
groups = df.groupby('match_id')

match_ids = df['match_id'].unique()
last_five = []
for id in match_ids:
  last_five.extend(groups.get_group(id).rolling(window=30).sum()['runs'].values.tolist())
# Out:
# <ipython-input-101-989dbd6af567>:6: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['batting_team', 'bowling_team', 'city'], dtype='object')
#   last_five.extend(groups.get_group(id).rolling(window=30).sum()['runs'].values.tolist())

# %%
last_five

# %%
df['last_five'] = last_five
df
# Out:
# <ipython-input-103-025f04bd8d27>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['last_five'] = last_five
#      match_id batting_team bowling_team  ball  runs  player_dismissed  \
# 0           3  West Indies        India   0.1     1                 0
# 1           3  West Indies        India   0.2     0                 0
# 2           3  West Indies        India   0.3     6                 0
# 3           3  West Indies        India   0.4     4                 0
# 4           3  West Indies        India   0.5     1                 0
# ..        ...          ...          ...   ...   ...               ...
# 116       954  New Zealand      England  19.2     1                 4
# ...

# %%
final_df=df.groupby('match_id').sum()['runs'].reset_index().merge(df,on='match_id')
# Out:
# <ipython-input-104-d83179bae6f9>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   final_df=df.groupby('match_id').sum()['runs'].reset_index().merge(df,on='match_id')

# %%
final_df = final_df[['batting_team','bowling_team','city','current_score','balls_left','wickets_left','crr','last_five','runs_x']]

# %%
final_data = final_df.copy()

# %%
final_df= final_data

# %%
final_df.isnull().sum()
# Out:
# batting_team         0
# bowling_team         0
# city                 0
# current_score        0
# balls_left           0
# wickets_left         0
# crr                  0
# last_five        12024
# runs_x               0
# dtype: int64

# %%
final_df.dropna(inplace=True)

# %%
final_df.isnull().sum()
# Out:
# batting_team     0
# bowling_team     0
# city             0
# current_score    0
# balls_left       0
# wickets_left     0
# crr              0
# last_five        0
# runs_x           0
# dtype: int64

# %%
final_df=final_df.sample(final_df.shape[0])

# %%
x= final_df.drop(columns= ['runs_x'])
y = final_df['runs_x']
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size= 0.2, random_state = 1)

# %%
x_test
# Out:
#        batting_team  bowling_team          city  current_score  balls_left  \
# 31602      Pakistan   New Zealand      Auckland            149          15
# 37112  South Africa     Australia     Cape Town            172           1
# 42671      Pakistan     Australia         Dubai             73          61
# 3038     Bangladesh      Pakistan        Lahore             86          43
# 551           India   West Indies    Lauderhill             65          75
# ...             ...           ...           ...            ...         ...
# 39548   New Zealand       England        London            123          42
# 21990  South Africa         India  Johannesburg             42          92
# 5957       Pakistan       England       Cardiff             65          69
# 10601     Australia      Pakistan    Chandigarh             56          79
# 48846     Australia  South Africa     Cape Town            123          44
#
#        wickets_left       crr  last_five
# ...

# %%
# from sklearn.preprocessing import LabelEncoder
# label_encoder = LabelEncoder()
# x_train['batting_team'] = label_encoder.fit_transform(x_train['batting_team'])
# x_train['bowling_team'] = label_encoder.fit_transform(x_train['bowling_team'])
# x_train['city'] = label_encoder.fit_transform(x_train['city'])

# x_test['batting_team'] = label_encoder.transform(x_test['batting_team'])
# x_test['bowling_team'] = label_encoder.transform(x_test['bowling_team'])
# x_test['city'] = label_encoder.transform(x_test['city'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'batting_team'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-81-e74d5f5c86f2> in <cell line: 7>()
# ...

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.metrics import r2_score,mean_absolute_error

# %%
trf = ColumnTransformer([('trf',OneHotEncoder(sparse=False,drop='first'),['batting_team','bowling_team','city'])],remainder='passthrough')

# %%
pipe = Pipeline(steps=[
    ('step1', trf),
    ('step2',StandardScaler()),
    ('step3', XGBRegressor(n_estimators=1000, learning_rate=0.2, max_depth=12, random_state=1))
])

# %%
pipe.fit(x_train,y_train)
y_pred= pipe.predict(x_test)
print(r2_score(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# 0.9891460232126301
# 1.5878117766937652

# %%
import pickle

# %%
pickle.dump(pipe,open('pipe.pkl','wb'))
